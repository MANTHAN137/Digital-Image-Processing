# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib

# %%
imageObj = cv2.imread('image1.png')

# %%
imageObj
# Out:
# array([[[187, 226, 218],
#         [188, 227, 219],
#         [175, 216, 208],
#         ...,
#         [122, 138, 144],
#         [137, 151, 157],
#         [146, 160, 166]],
#
#        [[185, 224, 216],
#         [165, 206, 198],
#         [146, 187, 179],
#         ...,
#         [124, 140, 146],
#         [126, 142, 148],
#         [131, 147, 153]],
#
#        [[158, 199, 192],
#         [130, 172, 165],
#         [119, 162, 153],
#         ...,
#         [136, 155, 158],
#         [118, 137, 140],
#         [112, 131, 134]],
#
#        ...,
#
#        [[ 50,  13, 169],
#         [ 49,  12, 168],
#         [ 47,  10, 166],
#         ...,
#         [ 52,  48,  54],
#         [ 52,  48,  54],
#         [ 52,  48,  54]],
#
#        [[ 50,  13, 169],
#         [ 49,  12, 168],
#         [ 47,  10, 166],
#         ...,
#         [ 37,  33,  39],
#         [ 37,  33,  39],
#         [ 38,  34,  40]],
#
#        [[ 50,  13, 169],
#         [ 49,  12, 168],
#         [ 47,  10, 166],
# ...

# %%
plt.axis("off")
plt.title("Original Image")
plt.imshow(cv2.cvtColor(imageObj, cv2.COLOR_BGR2RGB))
plt.show()

# %%
imageObj.shape
# Out:
# (1280, 960, 3)

# %%
list=[[0,-1,0],[-1,4,-1],[0,-1,0]]

# %%
x=[]
masker=[]

# %%
for i in range(1,imageObj.shape[0]-1):
    for j in range(1,imageObj.shape[1]-2):
        mask=0
        for k in range(3):
            for l in range(3):
                mask+=imageObj[i-1+k][j-1+l][0]*list[k][l]
        x.append(mask)
    masker.append(x)
    x=[]

# %%
plt.axis("off")
plt.title("Original Image")
plt.imshow(cv2.cvtColor(masker, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-1dcbce9d8200> in <module>
#       1 plt.axis("off")
#       2 plt.title("Original Image")
# ----> 3 plt.imshow(cv2.cvtColor(masker, cv2.COLOR_BGR2RGB))
#       4 plt.show()
#
# error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'cvtColor'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
